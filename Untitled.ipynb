# %%
import warnings
warnings.filterwarnings("ignore")

from ast import literal_eval
from itertools import combinations
from unidecode import unidecode

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

import lightgbm as lgb
import numpy as np
import pandas as pd

short_columns = dict([('FIELD_{0}'.format(i), str(i)) for i in range(1, 58)])
ignore_columns = '36 37 label id'.split()
unidecode_columns = 'province district maCv'.split()
object_columns = '7 8 9 10 11 12 13 17 18 19 20 23 24 25 26 27 28 29 3 30 31 35 38 39 40 42 43 44 45 district maCv province'.split()
oh_columns = '8 9 10 11 12 13 17 18 19 20 23 24 25 26 27 28 29 3 30 31 35 38 39 40 41 42 43 44 45 province'.split()
auto_columns = '1 2 3 4 5 6 14 15 16 21 22 32 33 34 46 50 51 52 53 54 55 56 57'.split()
elemenets_f7 = """AT BT CB CC CH CK CN DK DN DT GB GD HC HD HG HK HN HS HT HX KC LS 
                  MS ND NN NO PV QN QT SV TA TB TC TE TK TL TN TQ TS XB XD XK XN XV""".split()
params = {
    'objective'         : 'binary',    
    'metric'            : 'auc', 
    'nthread'           : 4,
    'learning_rate'     : 0.01,

    'num_leaves'        : 23,
    'feature_fraction'  : 0.106,
    'bagging_fraction'  : 0.825,
    'max_depth'         : -1,
    'lambda_l1'         : 0.2,
    'lambda_l2'         : 2.7,
    'min_split_gain'    : 0.007,
}

def gini(y_true, y_score):
    return roc_auc_score(y_true, y_score)*2 - 1

def lgb_gini(y_pred, dataset_true):
    y_true = dataset_true.get_label()
    return 'gini', gini(y_true, y_pred), True

def f3_to_year(x):
    if x == 0 or x == -1:
        return 0
    for i in range(1, 23):
        t = int(i*365.25) - 13
        if t - 30 <= x <= t + 30:
            return min(12, i)
    return -999

def transform(df):
    df.rename(columns=short_columns, inplace=True)
    columns = list(set(df.columns).difference(ignore_columns))
#     print(columns)
    for l, r in combinations(auto_columns, 2):
        for func in 'add subtract divide multiply'.split():
            df['auto_{0}_{1}_{2}'.format(func, l, r)] = getattr(np, func)(df[l], df[r])

    df['sum_14_15_32_33_34'] = df['14 15 32 33 34'.split()].sum(axis=1)
    
    f7_array = df['7'].apply(lambda x: '[]' if x != x else x).apply(literal_eval)
    df['cnt_7'] = f7_array.apply(len)
    for col in elemenets_f7:
        df['cnt_7_{0}'.format(func)] = f7_array.apply(lambda x: x.count(col))
        
    df[unidecode_columns] = df[unidecode_columns].applymap(lambda x: unidecode(x).lower() if x == x else x)
        
    for func in 'equal less greater subtract add'.split():
        df['age1_{0}_age2'.format(func)] = getattr(np, func)(df['age_source1'], df['age_source2'])

    df['3'] = df['3'].apply(f3_to_year)
    df['41'] = df['41'].replace({'I':1, 'II':2, 'III':3, 'IV':4, 'V':5, 'None':np.NaN}).astype(float)
    
    df['cnt_NaN'] = df[columns].isnull().sum(axis=1)
    df['cnt_True'] = df[columns].applymap(lambda x: isinstance(x, bool) and x).sum(axis=1)
    df['cnt_False'] = df[columns].applymap(lambda x: isinstance(x, bool) and not x).sum(axis=1)
    for name in 'TRUE FALSE None'.split():
        df['cnt_{0}'.format(name)] = df[columns].applymap(lambda x: x == name).sum(axis=1)
    for l, r in combinations('TRUE FALSE True False None NaN'.split(), 2):
        df['cnt_{0}_{1}_{2}'.format(func, l, r)] = df['cnt_{0}'.format(l)] + df['cnt_{0}'.format(r)]
        
    df = pd.concat([df, pd.get_dummies(df[oh_columns], columns=oh_columns, dummy_na=True).add_prefix('_')], axis=1)
    df[object_columns] = df[object_columns].astype('category')
    return df

train = pd.read_csv('input/train.csv')
test  = pd.read_csv('input/test.csv')
label = train.pop('label')

train = transform(train)
test = transform(test)
columns = sorted(set(train.columns).intersection(test.columns).difference(ignore_columns))

X_train, X_test, y_train = train[columns], test[columns], label
skf = StratifiedKFold(n_splits=4, random_state=3462873, shuffle=True)
preds = 0.0
feature_importance_df = pd.DataFrame()
for fold_, (itrain, ivalid) in enumerate(skf.split(X_train, y_train)):
    lgb_train = lgb.Dataset(X_train.iloc[itrain], y_train.iloc[itrain])
    lgb_eval  = lgb.Dataset(X_train.iloc[ivalid], y_train.iloc[ivalid], reference = lgb_train)
    model = lgb.train(params,
                lgb_train,
                num_boost_round = 99999,  
                early_stopping_rounds = 800,
                feval = lgb_gini,
                verbose_eval = 100,
                valid_sets = [lgb_train, lgb_eval])
    pred = model.predict(X_test)
    preds += pred/skf.n_splits
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = X_train.columns
    fold_importance_df["importance"] = model.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

# test['label'] = preds
# test[['id', 'label']].to_csv('submission.csv', index=False)
# Out:
# Training until validation scores don't improve for 800 rounds.
# [100]	training's auc: 0.876527	training's gini: 0.753055	valid_1's auc: 0.601204	valid_1's gini: 0.202409
# [200]	training's auc: 0.90273	training's gini: 0.80546	valid_1's auc: 0.603073	valid_1's gini: 0.206145
# [300]	training's auc: 0.917133	training's gini: 0.834266	valid_1's auc: 0.605689	valid_1's gini: 0.211379
# [400]	training's auc: 0.924395	training's gini: 0.84879	valid_1's auc: 0.601699	valid_1's gini: 0.203397
# [500]	training's auc: 0.928945	training's gini: 0.85789	valid_1's auc: 0.598311	valid_1's gini: 0.196622
# [600]	training's auc: 0.933226	training's gini: 0.866452	valid_1's auc: 0.596069	valid_1's gini: 0.192138
# [700]	training's auc: 0.936541	training's gini: 0.873083	valid_1's auc: 0.595466	valid_1's gini: 0.190932
# [800]	training's auc: 0.939146	training's gini: 0.878292	valid_1's auc: 0.594003	valid_1's gini: 0.188007
# [900]	training's auc: 0.941134	training's gini: 0.882267	valid_1's auc: 0.590973	valid_1's gini: 0.181945
# [1000]	training's auc: 0.943275	training's gini: 0.886551	valid_1's auc: 0.588272	valid_1's gini: 0.176543
# Early stopping, best iteration is:
# [272]	training's auc: 0.915097	training's gini: 0.830194	valid_1's auc: 0.606215	valid_1's gini: 0.212429
# Training until validation scores don't improve for 800 rounds.
# [100]	training's auc: 0.886969	training's gini: 0.773938	valid_1's auc: 0.650788	valid_1's gini: 0.301577
# [200]	training's auc: 0.913242	training's gini: 0.826483	valid_1's auc: 0.644664	valid_1's gini: 0.289328
# [300]	training's auc: 0.921437	training's gini: 0.842874	valid_1's auc: 0.640212	valid_1's gini: 0.280425
# [400]	training's auc: 0.927929	training's gini: 0.855857	valid_1's auc: 0.636583	valid_1's gini: 0.273166
# [500]	training's auc: 0.931117	training's gini: 0.862234	valid_1's auc: 0.631983	valid_1's gini: 0.263967
# [600]	training's auc: 0.935388	training's gini: 0.870775	valid_1's auc: 0.627581	valid_1's gini: 0.255163
# [700]	training's auc: 0.938945	training's gini: 0.87789	valid_1's auc: 0.62367	valid_1's gini: 0.24734
# [800]	training's auc: 0.941683	training's gini: 0.883365	valid_1's auc: 0.61885	valid_1's gini: 0.237699
# Early stopping, best iteration is:
# [91]	training's auc: 0.879826	training's gini: 0.759652	valid_1's auc: 0.653332	valid_1's gini: 0.306664
# Training until validation scores don't improve for 800 rounds.
# [100]	training's auc: 0.868464	training's gini: 0.736929	valid_1's auc: 0.605773	valid_1's gini: 0.211547
# [200]	training's auc: 0.903369	training's gini: 0.806739	valid_1's auc: 0.608847	valid_1's gini: 0.217693
# [300]	training's auc: 0.918962	training's gini: 0.837923	valid_1's auc: 0.613486	valid_1's gini: 0.226973
# [400]	training's auc: 0.92718	training's gini: 0.85436	valid_1's auc: 0.613461	valid_1's gini: 0.226921
# [500]	training's auc: 0.931942	training's gini: 0.863884	valid_1's auc: 0.609255	valid_1's gini: 0.21851
# [600]	training's auc: 0.935026	training's gini: 0.870052	valid_1's auc: 0.609117	valid_1's gini: 0.218234
# [700]	training's auc: 0.937986	training's gini: 0.875973	valid_1's auc: 0.607179	valid_1's gini: 0.214357
# [800]	training's auc: 0.940847	training's gini: 0.881694	valid_1's auc: 0.607816	valid_1's gini: 0.215632
# Early stopping, best iteration is:
# [6]	training's auc: 0.772725	training's gini: 0.545451	valid_1's auc: 0.622351	valid_1's gini: 0.244702
# Training until validation scores don't improve for 800 rounds.
# [100]	training's auc: 0.864853	training's gini: 0.729706	valid_1's auc: 0.623649	valid_1's gini: 0.247298
# [200]	training's auc: 0.902008	training's gini: 0.804016	valid_1's auc: 0.621918	valid_1's gini: 0.243836
# [300]	training's auc: 0.913184	training's gini: 0.826367	valid_1's auc: 0.618936	valid_1's gini: 0.237872
# [400]	training's auc: 0.919344	training's gini: 0.838688	valid_1's auc: 0.621639	valid_1's gini: 0.243277
# [500]	training's auc: 0.923988	training's gini: 0.847976	valid_1's auc: 0.620984	valid_1's gini: 0.241968
# [600]	training's auc: 0.92829	training's gini: 0.856581	valid_1's auc: 0.618302	valid_1's gini: 0.236604
# [700]	training's auc: 0.932164	training's gini: 0.864328	valid_1's auc: 0.616028	valid_1's gini: 0.232056
# [800]	training's auc: 0.936582	training's gini: 0.873163	valid_1's auc: 0.613738	valid_1's gini: 0.227475
# Early stopping, best iteration is:
# [20]	training's auc: 0.793009	training's gini: 0.586018	valid_1's auc: 0.636872	valid_1's gini: 0.273743

# %%
print(len(X_train.columns))
# Out:
# 1568

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:100].index)
best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,26))
sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance",ascending=False))
plt.title('LightGBM Features (averaged over folds)')
plt.tight_layout()
